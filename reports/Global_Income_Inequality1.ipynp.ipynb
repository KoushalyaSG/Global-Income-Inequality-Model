# %% [markdown]
# ##### 1. Project Overview
# ###### The objective of this project is to develop a predictive model to estimate the Gini Index (Income Inequality) based on key economic and social indicators.

# %% [markdown]
# ### 1.Dataset Overview

# %% [markdown]
# ###### .Total Records: 6,500
# ###### Total Features: 5
# ###### .TIme Period: 2000 – 2023
# ###### .Target Variable: Gini_Index

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Display settings
pd.set_option('display.max_columns', None)
sns.set_style("whitegrid")

# %%
df = pd.read_csv("C:\\Users\\kushi\\OneDrive\\documents1\\cleaned_dataset.csv")

# View rowsss
df.head(300)
# Out:
#     Country  Year  Gini_Index  Education_Spending_%GDP  Unemployment_%
# 0    Brazil  2015   41.188583                 4.981644        6.189960
# 1     India  2017   28.742018                 4.883997        7.355132
# 2    Brazil  2004   29.623825                 4.041603        4.801137
# 3    Brazil  2021   41.441344                 4.038214        6.612803
# 4     India  2003   33.749351                 4.085419        6.730546
# ..      ...   ...         ...                      ...             ...
# 295     USA  2018   23.952909                 5.301229        7.512697
# 296     USA  2007   23.820114                 2.660993        5.459521
# 297     USA  2019   41.106379                 3.604312        5.184572
# 298     USA  2007   40.062527                 5.005791        5.537041
# 299     USA  2009   31.299773                 4.097951        5.081524
#
# [300 rows x 5 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of         Country  Year  Gini_Index  Education_Spending_%GDP  Unemployment_%
# 0        Brazil  2015   41.188583                 4.981644        6.189960
# 1         India  2017   28.742018                 4.883997        7.355132
# 2        Brazil  2004   29.623825                 4.041603        4.801137
# 3        Brazil  2021   41.441344                 4.038214        6.612803
# 4         India  2003   33.749351                 4.085419        6.730546
# ...         ...   ...         ...                      ...             ...
# 6495  Indonesia  2006   53.316693                 4.311413        6.786635
# 6496  Indonesia  2009   48.496918                 4.678668        6.018918
# 6497         UK  2015   48.226017                 5.193643        8.648974
# 6498     Canada  2006   32.548758                 5.833002        6.646115
# 6499     France  2019   44.663063                 3.664612        6.050621
#
# [6500 rows x 5 columns]>

# %%
df.isnull().sum()
# Out:
# Country                    0
# Year                       0
# Gini_Index                 0
# Education_Spending_%GDP    0
# Unemployment_%             0
# dtype: int64

# %%
df.dtypes
# Out:
# Country                     object
# Year                         int64
# Gini_Index                 float64
# Education_Spending_%GDP    float64
# Unemployment_%             float64
# dtype: object

# %% [markdown]
# #### Descriptive Statistics

# %% [markdown]
# ###### Average year in dataset ≈ 2012, covering data from 2000 to 2023
# ###### Average standardized Gini Index ≈ -7.70, showing values are scaled rather than original inequality values.
# ###### Education spending (standardized) shows moderate variation, indicating differences across observations.
# ###### Unemployment rate (standardized) also varies across the dataset, with both below average and above-average levels included

# %%
df.describe()
# Out:
#               Year   Gini_Index  Education_Spending_%GDP  Unemployment_%
# count  6500.000000  6500.000000              6500.000000     6500.000000
# mean   2011.576462    35.497076                 4.551902        6.603004
# std       6.917234     6.755628                 0.815401        1.537466
# min    2000.000000    10.675699                 1.708176        0.284669
# 25%    2006.000000    31.024815                 3.999886        5.578670
# 50%    2012.000000    35.365558                 4.544550        6.603004
# 75%    2017.000000    39.587795                 5.069922        7.638149
# max    2023.000000    96.489105                 8.589112       14.001817

# %% [markdown]
# #### 3.Correlation Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm')
plt.title("Final Correlation Matrix")
plt.show()
