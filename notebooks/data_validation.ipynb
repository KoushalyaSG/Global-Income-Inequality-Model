# %%
import pandas as pd

stage3_path = r"C:\Users\Lenovo\Desktop\Intern mini project\Processed\feature_engineered_dataset.csv"

df = pd.read_csv(stage3_path)

print("Stage 3 Data Loaded")
print("Shape:", df.shape)
df.head()
# Out:
# Stage 3 Data Loaded
# Shape: (6500, 17)
#    Year  Gini_Index  Education_Spending_%GDP  Unemployment_%  Country_Canada  \
# 0  2015    0.842549                 0.527072       -0.268673           False
# 1  2017   -0.999993                 0.407309        0.489238           False
# 2  2004   -0.869453                -0.625874       -1.172062           False
# 3  2021    0.879966                -0.630030        0.006374           False
# 4  2003   -0.258727                -0.572135        0.082963           False
#
#    Country_China  Country_France  Country_Germany  Country_India  \
# 0          False           False            False          False
# 1          False           False            False           True
# 2          False           False            False          False
# 3          False           False            False          False
# 4          False           False            False           True
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6500 entries, 0 to 6499
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     6500 non-null   int64
#  1   Gini_Index               6500 non-null   float64
#  2   Education_Spending_%GDP  6500 non-null   float64
#  3   Unemployment_%           6500 non-null   float64
#  4   Country_Canada           6500 non-null   bool
#  5   Country_China            6500 non-null   bool
#  6   Country_France           6500 non-null   bool
#  7   Country_Germany          6500 non-null   bool
#  8   Country_India            6500 non-null   bool
#  9   Country_Indonesia        6500 non-null   bool
#  10  Country_Japan            6500 non-null   bool
#  11  Country_South Africa     6500 non-null   bool
#  12  Country_UK               6500 non-null   bool
#  13  Country_USA              6500 non-null   bool
# ...

# %%
df.isnull().sum()
# Out:
# Year                       0
# Gini_Index                 0
# Education_Spending_%GDP    0
# Unemployment_%             0
# Country_Canada             0
# Country_China              0
# Country_France             0
# Country_Germany            0
# Country_India              0
# Country_Indonesia          0
# Country_Japan              0
# Country_South Africa       0
# Country_UK                 0
# Country_USA                0
# Education_Efficiency       0
# Edu_to_Unemp_Ratio         0
# Economic_Stress_Index      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               Year    Gini_Index  Education_Spending_%GDP  Unemployment_%  \
# count  6500.000000  6.500000e+03             6.500000e+03    6.500000e+03
# mean   2011.576462 -7.695724e-16             7.608273e-16   -4.285119e-16
# std       6.917234  1.000077e+00             1.000077e+00    1.000077e+00
# min    2000.000000 -3.674460e+00            -3.487787e+00   -4.109893e+00
# 25%    2006.000000 -6.620562e-01            -6.770391e-01   -6.662994e-01
# 50%    2012.000000 -1.946944e-02            -9.016990e-03   -5.777342e-16
# 75%    2017.000000  6.055742e-01             6.353440e-01    6.733318e-01
# max    2023.000000  9.029024e+00             4.951578e+00    4.812713e+00
#
#        Education_Efficiency  Edu_to_Unemp_Ratio  Economic_Stress_Index
# count          6.500000e+03        6.500000e+03           6.500000e+03
# mean           6.799628e+02        3.989244e+02          -1.189339e-15
# std            9.094069e+04        7.868290e+04           1.432704e+00
# ...

# %%
df[['Education_Efficiency',
    'Economic_Stress_Index',
    'Edu_to_Unemp_Ratio']].describe()
# Out:
#        Education_Efficiency  Economic_Stress_Index  Edu_to_Unemp_Ratio
# count          6.500000e+03           6.500000e+03        6.500000e+03
# mean           6.799628e+02          -1.189339e-15        3.989244e+02
# std            9.094069e+04           1.432704e+00        7.868290e+04
# min           -2.279019e+06          -4.730330e+00       -1.811771e+06
# 25%           -9.827268e-01          -9.563305e-01       -9.226409e-01
# 50%            4.087643e-02          -2.932425e-02        2.261300e-02
# 75%            1.073360e+00           9.110478e-01        1.014749e+00
# max            2.068151e+06           8.775491e+00        1.779232e+06

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm')
plt.title("Final Correlation Matrix")
plt.show()

# %%
print("Final Dataset Validation Summary")
print("----------------------------------")
print("Total Rows:", df.shape[0])
print("Total Columns:", df.shape[1])
print("Missing Values:", df.isnull().sum().sum())
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Final Dataset Validation Summary
# ----------------------------------
# Total Rows: 6500
# Total Columns: 17
# Missing Values: 0
# Duplicate Rows: 0

# %%
# Define final save path
final_path = r"C:\Users\Lenovo\Desktop\Intern mini project\Processed\final_validated_dataset.csv"

# Save file
df.to_csv(final_path, index=False)

# Confirmation
rows, cols = df.shape

print("Final Validated Dataset Saved Successfully ✅")
print("--------------------------------------------")
print(f"Total Rows: {rows}")
print(f"Total Columns: {cols}")
print("Missing Values:", df.isnull().sum().sum())
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[13], line 5
#       2 final_path = r"C:\Users\Lenovo\Desktop\Intern mini project\Processed"
#       4 # Save file
# ----> 5 df.to_csv(final_path, index=False)
#       7 # Confirmation
#       8 rows, cols = df.shape
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
